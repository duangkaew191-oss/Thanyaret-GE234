# %% [markdown]
# # 🛰️ Lab 2: การใช้งาน Loop และ If-Else
# ## วิชา GE 234 Basic Programming for Geographers
#
# ### 🎯 **วัตถุประสงค์**
# 1. เข้าใจโครงสร้างการควบคุมแบบ **Loop** (`for`, `while`) และ **เงื่อนไข** (`if-else`)
# 2. สามารถใช้ `for` และ `while` loop เพื่อประมวลผลข้อมูลซ้ำ ๆ ได้
# 3. ใช้ `if-else` เพื่อกำหนดเงื่อนไขในการตัดสินใจ
# 4. นำไปประยุกต์ใช้กับข้อมูลทางภูมิศาสตร์ เช่น การคัดกรองข้อมูลพิกัดและการวิเคราะห์ข้อมูล Raster
#
# ---
#
# ## 🔹 ตัวอย่างที่ 1: การใช้ `for loop` เพื่อแสดงค่าพิกัด

# %%
# พิกัดของสถานที่สำคัญในประเทศไทย
locations = {
    "Bangkok": (13.7563, 100.5018),
    "Chiang Mai": (18.7883, 98.9853),
    "Phuket": (7.8804, 98.3923),
    "Ubon Ratchathani": (15.2287, 104.8564)
}

# วนลูปแสดงค่าพิกัด
for city, coord in locations.items():
    print(f"{city}: Latitude {coord[0]}, Longitude {coord[1]}")

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 2: การใช้ `if-else` กรองข้อมูลพิกัด

# %%
for city, coord in locations.items():
    if coord[0] > 16:
        print(f"{city} อยู่ทางภาคเหนือของประเทศไทย")
    else:
        print(f"{city} ไม่ใช่จังหวัดทางภาคเหนือ")

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 3: ใช้ `while loop` นับจำนวนจุดข้อมูล

# %%
points = [(13.7563, 100.5018), (18.7883, 98.9853), (7.8804, 98.3923)]
count = 0

while count < len(points):
    print(f"Point {count + 1}: {points[count]}")
    count += 1

# %% [markdown]
# ## 🔹 ตัวอย่างที่ 4: วิเคราะห์ข้อมูล Raster ด้วย `for loop`

# %%
import numpy as np

# จำลองข้อมูล NDVI (Normalized Difference Vegetation Index)
ndvi = np.array([
    [0.2, 0.4, 0.5],
    [0.1, 0.3, 0.7],
    [0.6, 0.8, 0.2]
])

# วนลูปตรวจสอบค่าพืชพรรณ
for row in range(ndvi.shape[0]):
    for col in range(ndvi.shape[1]):
        if ndvi[row, col] > 0.3:
            print(f"พิกัด ({row}, {col}) มีพืชพรรณหนาแน่น (NDVI={ndvi[row, col]})")

# %% [markdown]
# # 📝 **กิจกรรมในแลป**
#
# 1. **แบบฝึกหัด 1**: เขียน `for loop` เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง
# 2. **แบบฝึกหัด 2**: ใช้ `if-else` เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด
# 3. **แบบฝึกหัด 3**: ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°
# 4. **แบบฝึกหัด 4**: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %% [markdown]
# แบบฝึกหัด 1: เขียน `for loop` เพื่อแสดงชื่อจังหวัดและพิกัดจากลิสต์ของคุณเอง

# %%
my_locations = {
    "Nakhon Ratchasima": (14.9745, 102.0911),
    "Khon Kaen": (16.4444, 102.8369),
    "Surat Thani": (9.1397, 99.3275),
    "Ayutthaya": (14.3541, 100.5606)
}


print("--- แสดงชื่อจังหวัดและพิกัดจากลิสต์ของฉัน ---")
for city, coord in my_locations.items():
    print(f"จังหวัด {city}: ละติจูด {coord[0]}, ลองจิจูด {coord[1]}")
# Out:
# --- แสดงชื่อจังหวัดและพิกัดจากลิสต์ของฉัน ---
# จังหวัด Nakhon Ratchasima: ละติจูด 14.9745, ลองจิจูด 102.0911
# จังหวัด Khon Kaen: ละติจูด 16.4444, ลองจิจูด 102.8369
# จังหวัด Surat Thani: ละติจูด 9.1397, ลองจิจูด 99.3275
# จังหวัด Ayutthaya: ละติจูด 14.3541, ลองจิจูด 100.5606

# %% [markdown]
# แบบฝึกหัด 2: ใช้ if-else เพื่อแยกแยะพื้นที่ที่เป็นภูเขาและพื้นที่ราบจากลิสต์ของพิกัด

# %%
locations_for_exercise_2 = {
    "Doi Inthanon": (18.5833, 98.4861),
    "Ayutthaya": (14.3541, 100.5606),
    "Phu Thap Buek": (16.9242, 101.1272),
    "Bangkok": (13.7563, 100.5018)
}
mountainous_latitude_threshold = 16.0

print("--- การจำแนกพื้นที่ภูเขาและที่ราบ ---")
for place, coord in locations_for_exercise_2.items():
    latitude = coord[0]
    longitude = coord[1]

    if latitude > mountainous_latitude_threshold:
        print(f"{place} (ละติจูด {latitude:.2f}) เป็นพื้นที่ **ภูเขา**")
    else:
        print(f"{place} (ละติจูด {latitude:.2f}) เป็นพื้นที่ **ที่ราบ**")
# Out:
# --- การจำแนกพื้นที่ภูเขาและที่ราบ ---
# Doi Inthanon (ละติจูด 18.58) เป็นพื้นที่ **ภูเขา**
# Ayutthaya (ละติจูด 14.35) เป็นพื้นที่ **ที่ราบ**
# Phu Thap Buek (ละติจูด 16.92) เป็นพื้นที่ **ภูเขา**
# Bangkok (ละติจูด 13.76) เป็นพื้นที่ **ที่ราบ**

# %% [markdown]
# แบบฝึกหัด 3 ใช้ `while loop` เพื่อวนลูปและแสดงค่าละติจูดจากลิสต์จนกว่าจะพบค่าต่ำกว่า 10°

# %%
latitudes = [18.7883, 15.2287, 13.7563, 7.8804, 16.4444]

index = 0
print("--- แสดงค่าละติจูดจนกว่าจะพบค่าต่ำกว่า 10° ---")
while index < len(latitudes):
    current_latitude = latitudes[index]
    print(f"ละติจูดปัจจุบัน: {current_latitude}°")
    if current_latitude < 10:
        print(f"พบละติจูดที่ต่ำกว่า 10° แล้ว: {current_latitude}° หยุดการวนลูป")
        break
    index += 1

if index == len(latitudes):
    print("ไม่พบละติจูดที่ต่ำกว่า 10° ในลิสต์")
# Out:
# --- แสดงค่าละติจูดจนกว่าจะพบค่าต่ำกว่า 10° ---
# ละติจูดปัจจุบัน: 18.7883°
# ละติจูดปัจจุบัน: 15.2287°
# ละติจูดปัจจุบัน: 13.7563°
# ละติจูดปัจจุบัน: 7.8804°
# พบละติจูดที่ต่ำกว่า 10° แล้ว: 7.8804° หยุดการวนลูป

# %% [markdown]
# แบบฝึกหัด 4: ใช้ `for loop` วิเคราะห์ค่า NDVI และหาค่าพื้นที่ที่มีสภาพแห้งแล้ง (NDVI < 0.2)

# %%
import numpy as np


# ค่าที่ต่ำกว่า 0.2 โดยทั่วไปบ่งชี้ถึงพื้นที่ที่มีพืชพรรณน้อยหรือไม่แข็งแรง (อาจแห้งแล้ง)
ndvi_data = np.array([
    [0.25, 0.35, 0.15],
    [0.18, 0.42, 0.50],
    [0.60, 0.10, 0.30]
])

print("--- การวิเคราะห์พื้นที่แห้งแล้งจากค่า NDVI ---")
# วนลูปเพื่อตรวจสอบแต่ละเซลล์ในข้อมูล NDVI
for row_idx in range(ndvi_data.shape[0]):
    for col_idx in range(ndvi_data.shape[1]):
        current_ndvi = ndvi_data[row_idx, col_idx]

        # ตรวจสอบเงื่อนไขว่าค่า NDVI ต่ำกว่า 0.2 หรือไม่
        if current_ndvi < 0.2:
            print(f"พิกัด ({row_idx}, {col_idx}) มีค่า NDVI = {current_ndvi:.2f} ซึ่งบ่งชี้ถึง **สภาพแห้งแล้ง**")
        else:
            print(f"พิกัด ({row_idx}, {col_idx}) มีค่า NDVI = {current_ndvi:.2f} (พืชพรรณปกติ/หนาแน่น)")
# Out:
# --- การวิเคราะห์พื้นที่แห้งแล้งจากค่า NDVI ---
# พิกัด (0, 0) มีค่า NDVI = 0.25 (พืชพรรณปกติ/หนาแน่น)
# พิกัด (0, 1) มีค่า NDVI = 0.35 (พืชพรรณปกติ/หนาแน่น)
# พิกัด (0, 2) มีค่า NDVI = 0.15 ซึ่งบ่งชี้ถึง **สภาพแห้งแล้ง**
# พิกัด (1, 0) มีค่า NDVI = 0.18 ซึ่งบ่งชี้ถึง **สภาพแห้งแล้ง**
# พิกัด (1, 1) มีค่า NDVI = 0.42 (พืชพรรณปกติ/หนาแน่น)
# พิกัด (1, 2) มีค่า NDVI = 0.50 (พืชพรรณปกติ/หนาแน่น)
# พิกัด (2, 0) มีค่า NDVI = 0.60 (พืชพรรณปกติ/หนาแน่น)
# พิกัด (2, 1) มีค่า NDVI = 0.10 ซึ่งบ่งชี้ถึง **สภาพแห้งแล้ง**
# พิกัด (2, 2) มีค่า NDVI = 0.30 (พืชพรรณปกติ/หนาแน่น)
